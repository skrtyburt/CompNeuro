# %% [markdown]
# <a href="https://colab.research.google.com/github/skrtyburt/CompNeuro/blob/main/HebbianLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neurodynex
from neurodynex.ojas_rule.oja import *
# Out:
# ...
#      |████████████████████████████████| 69 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 8.8 MB/s
# ...

# %%
cloud = make_cloud()  # generate data points
wcourse = learn(cloud)  # learn weights and return timecourse

# %%
# %matplotlib inline 
import neurodynex.ojas_rule.oja as oja
import matplotlib.pyplot as plt

cloud = oja.make_cloud(n=200, ratio=.3, angle=60)
wcourse = oja.learn(cloud, initial_angle=-20, eta=0.04)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.4718919642891174,0.8820939329340348)
